# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %%
islaidos=pd.read_csv("Gyventojuislaidos.csv")

# %%
#Išlaidos#

# %%
islaidos.info() #paklausti del strukturoje esanciu beveik visu string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438262 entries, 0 to 438261
# Data columns (total 10 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   _type            438262 non-null  object
#  1   _id              438262 non-null  object
#  2   _revision        438262 non-null  object
#  3   metai            438262 non-null  int64
#  4   sav_kodas        438262 non-null  int64
#  5   sav_pavadinimas  438262 non-null  object
#  6   mm_kodas         438262 non-null  object
#  7   ir_kodas         438262 non-null  int64
#  8   pavadinimas      438262 non-null  object
#  9   suma             438262 non-null  float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 33.4+ MB

# %%
islaidos.nunique()
# Out:
# _type                   1
# _id                438262
# _revision          438262
# metai                   1
# sav_kodas              60
# sav_pavadinimas        60
# mm_kodas           384280
# ir_kodas                9
# pavadinimas             9
# suma                 5943
# dtype: int64

# %%
islaidos.head(10)
# Out:
#                                                _type  \
# 0  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 1  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 2  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 3  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 4  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 5  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 6  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 7  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 8  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 9  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
#
#                                     _id                             _revision  \
# 0  f44f4a67-e4ae-433e-a971-fc734cdf082a  a520537c-6bea-4251-a947-7a65a60e3c0f
# 1  879409f4-a478-43a9-997a-d185169f230b  4113b4e9-4f76-426c-8a44-0a91f1baf896
# 2  1a2d1af6-da46-4c4f-8f12-1787b41d44d4  b134333d-1335-4421-af33-d397dd3dbc3d
# 3  dc7a74a7-8328-415d-bf3b-ac92ee0e851d  ba3a87c3-3d0b-4ca2-b365-c45e70c2cb09
# 4  e70b98aa-fab7-4893-a159-d549e764de3d  11313b1c-88e6-42c0-989b-aa619314ee5c
# 5  6f877980-46da-40ff-b012-400770600599  e436dbde-1623-4579-bb92-0bb251de9cb7
# 6  31a6ebd8-4b2a-4a06-856a-e98c87dbca03  b958eeaf-f629-4e58-b013-4078de7f5e4c
# 7  ecafc5a6-bcb0-4b59-8c4a-78fda2835711  fb48d13b-0542-4a4a-818c-907f3583cdfb
# 8  8bc965d5-2873-4c72-b236-35e738e2c9d6  15df3f1e-15b9-41ea-89a6-577ffc5b54ad
# 9  cca32354-29ac-4d69-a013-0ed6aa3442d9  8321ca54-b33e-4aa0-b657-af2a575df005
#
#    metai  sav_kodas      sav_pavadinimas  \
# 0   2020         19        Kauno m. sav.
# 1   2020         13     Vilniaus m. sav.
# 2   2020         13     Vilniaus m. sav.
# 3   2020         13     Vilniaus m. sav.
# 4   2020         13     Vilniaus m. sav.
# 5   2020         13     Vilniaus m. sav.
# 6   2020         39  Vilkaviškio r. sav.
# 7   2020         11      Alytaus m. sav.
# 8   2020         38      Varėnos r. sav.
# 9   2020         46      Jonavos r. sav.
#
#                                             mm_kodas  ir_kodas  \
# 0  db9f2c139efdf133098956d9f057ebce1c6e078eb4fcc2...         2
# 1  3cdc64e4d6a7dce93ef20a78335786c36b2b19215cb7d0...         1
# 2  8d9ad45da178a723551c78490ab29ba7d3e7b0c6c995d0...         6
# 3  c17883ac6b4dae58af45cead71157f6ddcdcf4bf92faca...         7
# 4  448c8fe614853c1ddc5ebd62c607df418d4855aba08968...         1
# 5  5d191d3617fb4eb674b648303e2ff90dde2ba0266a92ea...         1
# 6  9a3d8994247e0d5bc2697506b7f439b3fdc3fc6efbef02...         1
# 7  e639ef9b9e6d322b276acac5118b9d73d8aecfbd5b11ca...         7
# 8  323911d5b5f37b88b04610a3b1719de523a32ab56dca0a...         7
# 9  c5a188f61b9f60a960123b0c57695ffecbbccb33f40682...         1
#
#                                          pavadinimas    suma
# 0          Įmokos už aukštąjį ar profesinį mokymąsi.   780.0
# 1                           Gyvybės draudimo įmokos.   725.0
# 2  Pastatų, statinių remonto, apdailos (išskyrus ...    45.0
# 3  Lengvųjų automobilių remonto paslaugų išlaidos...   300.0
# 4                           Gyvybės draudimo įmokos.   480.0
# 5                           Gyvybės draudimo įmokos.  2253.0
# 6                           Gyvybės draudimo įmokos.  1200.0
# 7  Lengvųjų automobilių remonto paslaugų išlaidos...   261.0
# 8  Lengvųjų automobilių remonto paslaugų išlaidos...   850.0
# 9                           Gyvybės draudimo įmokos.   720.0

# %%
islaidos['suma'].nlargest(n=10) #10 didziausiu islaidu
#prideti ir rusi/savivaldybe
#is apraso "Išlaidų suma esanti virš 600000 eurų yra fiksuojama 600000 verte"
# Out:
# 169807    600000.0
# 37395     550000.0
# 47629     499171.0
# 163545    300000.0
# 370122    201749.0
# 240827    176830.0
# 5975      170000.0
# 181639    150000.0
# 232536    117396.0
# 173694    101500.0
# Name: suma, dtype: float64

# %%
islaidos['suma'].nsmallest(n=10) #KAIP IMTI BE NULIU IR PRIDETI RUSI ARBA ISTRINTI NULINES
# Out:
# 178     0.0
# 854     0.0
# 1316    0.0
# 1676    0.0
# 2230    0.0
# 2293    0.0
# 2539    0.0
# 3183    0.0
# 3330    0.0
# 5341    0.0
# Name: suma, dtype: float64

# %%
#------------RUSYS----------------#

# %%
islaidos_rusys=islaidos.groupby(['ir_kodas', 'pavadinimas']).sum(['suma']).drop(['metai','sav_kodas'],axis=1)
islaidos_rusys #pagal islaidu rusies kodus susumuota islaidu sumos
# Out:
#                                                                     suma
# ir_kodas pavadinimas
# 1        Gyvybės draudimo įmokos.                            206582878.0
# 2        Įmokos už aukštąjį ar profesinį mokymąsi.            50876033.0
# 3        Būsto kredito, suteikto iki 2008-12-31, palūkanos.   17811456.0
# 4        Pensijų kaupimo įmokos.                              17515718.0
# 5        Grąžintas studijų kreditas.                           3467652.0
# 6        Pastatų, statinių remonto, apdailos (išskyrus r...   17503277.0
# 7        Lengvųjų automobilių remonto paslaugų išlaidos ...    6524849.0
# 8        Nepilnamečių (iki 18 metų) vaikų (įvaikių, glob...     518580.0
# 9        Įmokų į pensijų fondą dalis, viršijanti 3 proce...    2212301.0

# %%
mpl.rc('figure', figsize=(10,10))
islaidos_rusys.reset_index().plot(x='ir_kodas', y='suma', c = 'red', marker = 'o',  markersize=7, grid = True).legend(labels = ['Suma'])
plt.xlabel("Išlaidų rūšies kodas")
plt.ylabel("Išlaidų suma per 2020 m.")
# Out:
# Text(0, 0.5, 'Išlaidų suma per 2020 m.')

# %%
islaidos_dazniai=islaidos.value_counts(['ir_kodas','pavadinimas']).sort_index()
islaidos_dazniai
#suskaiciuota kiek kiekvienos rusies (pagal koda ir pavadinima) yra islaidu duomenyse
# Out:
# ir_kodas  pavadinimas
# 1         Gyvybės draudimo įmokos.                                                                                                           273174
# 2         Įmokos už aukštąjį ar profesinį mokymąsi.                                                                                           41663
# 3         Būsto kredito, suteikto iki 2008-12-31, palūkanos.                                                                                  48815
# 4         Pensijų kaupimo įmokos.                                                                                                             29542
# 5         Grąžintas studijų kreditas.                                                                                                         12745
# 6         Pastatų, statinių remonto, apdailos (išskyrus renovaciją) darbų išlaidos.                                                            7192
# 7         Lengvųjų automobilių remonto paslaugų išlaidos (neįskaitant atsarginių detalių, eksploatacinių medžiagų kainos).                    18340
# 8         Nepilnamečių (iki 18 metų) vaikų (įvaikių, globotinių, kuriems nustatyta nuolatinė globa šeimoje) priežiūros paslaugų išlaidos.       321
# 9         Įmokų į pensijų fondą dalis, viršijanti 3 procentus gyventojo pajamų, nuo kurių mokamos valstybinio socialinio draudimo įmokos.      6470
# dtype: int64

# %%
mpl.rc('figure', figsize=(20,10))
islaidos_dazniai.reset_index().plot(x='ir_kodas', y=0, c = 'red', marker = 'o',  markersize=7, grid = True).legend(labels = ['Dažniai'])
plt.xlabel("Išlaidų rūšies kodas")
plt.ylabel("Dažniai")
# Out:
# Text(0, 0.5, 'Dažniai')

# %%
islaidos_vidurkiai=islaidos.groupby(['ir_kodas','pavadinimas']).mean().round(2).sort_values(by = 'ir_kodas').drop(['metai','sav_kodas'], axis=1)
islaidos_vidurkiai
# Out:
#                                                                     suma
# pavadinimas                                        ir_kodas
# Pastatų, statinių remonto, apdailos (išskyrus r... 6         2433.714822
# Nepilnamečių (iki 18 metų) vaikų (įvaikių, glob... 8         1615.514019
# Įmokos už aukštąjį ar profesinį mokymąsi.          2         1221.132252
# Gyvybės draudimo įmokos.                           1          756.231845
# Pensijų kaupimo įmokos.                            4          592.909011
# Būsto kredito, suteikto iki 2008-12-31, palūkanos. 3          364.876698
# Lengvųjų automobilių remonto paslaugų išlaidos ... 7          355.771483
# Įmokų į pensijų fondą dalis, viršijanti 3 proce... 9          341.932148
# Grąžintas studijų kreditas.                        5          272.079404

# %%
mpl.rc('figure', figsize=(10,10))
islaidos_vidurkiai.reset_index().plot(x='ir_kodas', y='suma', c = 'red', marker = 'o',  markersize=7, grid = True).legend(labels = ['Vidurkiai'])
plt.xlabel("Išlaidų rūšies kodas")
plt.ylabel("2020 m. vidurkis")
# Out:
# Text(0, 0.5, '2020 m. vidurkis')

# %%
mpl.rc('figure', figsize=(20,10))
islaidos_dv = [islaidos_dazniai,islaidos_vidurkiai]
result=pd.concat(islaidos_dv)
result.hist() #0 pakeisti i daznius
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'suma'}>]], dtype=object)

# %%
islaidos_dazniai.max()
# Out:
# 273174

# %%
#---------------SAVIVALDYBES------------------#

# %%
islaidos_sav=islaidos.groupby(['sav_kodas', 'sav_pavadinimas']).sum(['suma']).sort_values(by ='sav_kodas').drop(['metai','ir_kodas'],axis=1)#kiek kiekvienam rusies savivaldybes kodui priklauso islaidu
islaidos_sav['suma'].nlargest(n=10)
# Out:
# sav_kodas  sav_pavadinimas
# 13         Vilniaus m. sav.     96399144.0
# 19         Kauno m. sav.        41810790.0
# 21         Klaipėdos m. sav.    22458718.0
# 52         Kauno r. sav.        13643157.0
# 41         Vilniaus r. sav.     12322606.0
# 29         Šiaulių m. sav.      10465143.0
# 55         Klaipėdos r. sav.     8801178.0
# 27         Panevėžio m. sav.     8409185.0
# 18         Marijampolės sav.     5310484.0
# 61         Mažeikių r. sav.      5163822.0
# Name: suma, dtype: float64

# %%
islaidos_sav['suma'].nsmallest(n=10).sort_values(ascending = False)
# Out:
# sav_kodas  sav_pavadinimas
# 75         Skuodo r. sav.       1102492.0
# 57         Kupiškio r. sav.     1067987.0
# 45         Ignalinos r. sav.    1055510.0
# 89         Širvintų r. sav.     1029394.0
# 43         Zarasų r. sav.        866026.0
# 58         Kazlų Rūdos sav.      799997.0
# 74         Rietavo sav.          662767.0
# 48         Kalvarijos sav.       626472.0
# 63         Pagėgių sav.          489817.0
# 12         Birštono sav.         407496.0
# Name: suma, dtype: float64

# %%
mpl.rc('figure', figsize=(20,10))
islaidos_sav.reset_index().plot(x='sav_kodas', y='suma', c = 'blue', marker = 'o',  markersize=3, grid = True).legend(labels = ['Išlaidos'])
plt.xlabel("Savivaldybės kodas")
plt.ylabel("Išlaidų savivaldybėse suma (2020 m.)")
# Out:
# Text(0, 0.5, 'Išlaidų savivaldybėse suma (2020 m.)')

# %%
dazniai_sav = islaidos.value_counts(['sav_kodas','sav_pavadinimas']).sort_index()
dazniai_sav.head(5)
# Out:
# sav_kodas  sav_pavadinimas
# 11         Alytaus m. sav.        7698
# 12         Birštono sav.           562
# 13         Vilniaus m. sav.     118538
# 15         Druskininkų sav.       2882
# 18         Marijampolės sav.      7713
# dtype: int64

# %%
mpl.rc('figure', figsize=(20,10))
dazniai_sav.reset_index().plot(x='sav_kodas', y=0, c = 'red', marker = 'o',  markersize=7, grid = True).legend(labels = ['Dažniai'])
plt.xlabel("Savivaldybės kodas")
plt.ylabel("Dažniai")
# Out:
# Text(0, 0.5, 'Dažniai')

# %%
vidurkiai_sav=islaidos.groupby(['sav_kodas','sav_pavadinimas']).mean().round(2).drop(['metai', 'ir_kodas'], axis=1).sort_index()
vidurkiai_sav.head(10)
# Out:
#                                 suma
# sav_kodas sav_pavadinimas
# 11        Alytaus m. sav.     652.17
# 12        Birštono sav.       725.08
# 13        Vilniaus m. sav.    813.23
# 15        Druskininkų sav.    660.06
# 18        Marijampolės sav.   688.51
# 19        Kauno m. sav.       759.15
# 21        Klaipėdos m. sav.   768.11
# 23        Neringos sav.      1055.92
# 25        Palangos m. sav.    859.13
# 27        Panevėžio m. sav.   652.79

# %%
mpl.rc('figure', figsize=(20,10))
vidurkiai_sav.reset_index().plot(x='sav_kodas', y='suma', c = 'red', marker = 'o',  markersize=7, grid = True).legend(labels = ['Vidurkiai'])
plt.xlabel("Savivaldybės kodas")
plt.ylabel("Išlaidų savivaldybėse vidurkiai (2020 m.)")
# Out:
# Text(0, 0.5, 'Išlaidų savivaldybėse vidurkiai (2020 m.)')

# %%
islaidos.loc[islaidos['sav_kodas'] == 23]
# Out:
#                                                     _type  \
# 519     datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 887     datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 1476    datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 1584    datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 1838    datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# ...                                                   ...
# 438251  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 438253  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 438258  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 438259  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
# 438261  datasets/gov/vmi/gyventoju_islaidos/GyventojuI...
#
#                                          _id  \
# 519     a617e78f-ad7f-4cb0-8a82-983cce95021b
# 887     fd34f795-c4d3-4e28-9a23-47dae1e3b911
# 1476    cd1cb93e-bccd-48ea-a966-fc16d1f80374
# 1584    597526ea-c7ad-4258-8c37-32ac4ef979a8
# 1838    9ef26d52-9c42-4822-9e84-925651c51c81
# ...                                      ...
# 438251  da8474df-4418-4864-8816-29b78352c03b
# 438253  a941a591-6c6c-4261-8ff6-7d099a2dc456
# 438258  b8d636b8-77ef-453d-b90f-dbdc5be45379
# 438259  a7987574-8ea3-40c6-b5a7-7e01a5210efd
# 438261  e35f60ad-0e88-45cc-9de5-170bf37b6b95
#
#                                    _revision  metai  sav_kodas  \
# 519     18f26bba-4468-42c1-9346-edd0de0809a9   2020         23
# 887     926633db-d7c6-43dd-8706-d735492e4ce1   2020         23
# 1476    24dfe205-58e2-4bee-9719-ed6d1e3e0105   2020         23
# 1584    4df8f27a-e9bf-42c9-ac32-7e868f9e3a29   2020         23
# 1838    8ade3959-5824-4d47-a201-66a2c66a8e2f   2020         23
# ...                                      ...    ...        ...
# 438251  a45856cb-d98f-4bf6-aba7-8eab18ac2343   2020         23
# 438253  57cccc63-58cb-4332-bfdf-ca1924af0e73   2020         23
# 438258  57662b69-7f3f-4d10-b616-235cdeb15c44   2020         23
# 438259  bc079e98-21bf-4e8f-8886-279aeea39940   2020         23
# 438261  69ebae60-5960-44a4-abaf-aa59571c04dd   2020         23
#
#        sav_pavadinimas                                           mm_kodas  \
# 519      Neringos sav.  a492137136ff1349e3a17707924c8d9e949cd9032af39f...
# 887      Neringos sav.  529e4ad97e2441b5352b2c6d15eacd0137a898c9ad3e90...
# 1476     Neringos sav.  dc4bea28dfb84abe7c60fd3cf5ae785d98bdbafd836310...
# 1584     Neringos sav.  6ce39280b0465382d371a7a943af20de7bcc3d882e73af...
# 1838     Neringos sav.  afe244ba18b20b4981b99dbbcc4ccdacecc03be332754f...
# ...                ...                                                ...
# 438251   Neringos sav.  419c138a6b9e7ed1eb38fa0d9a8ab5708b70bc56a9a9dc...
# 438253   Neringos sav.  1e48a59327e90460065f31b6bb4ff6a7a079ae2a0d862b...
# 438258   Neringos sav.  aeb9c8d3a431b15cddbb62c9aad743ab13b156d2ccd69f...
# 438259   Neringos sav.  8615b915f33dada517c1882e3e3147065cd14bead0a5a7...
# 438261   Neringos sav.  3e88d97749517544c44b6ce38e2dc0b00855111f9bc86f...
#
#         ir_kodas                                        pavadinimas    suma
# 519            2          Įmokos už aukštąjį ar profesinį mokymąsi.   876.0
# 887            1                           Gyvybės draudimo įmokos.   500.0
# 1476           3  Būsto kredito, suteikto iki 2008-12-31, palūka...    57.0
# 1584           1                           Gyvybės draudimo įmokos.   868.0
# 1838           1                           Gyvybės draudimo įmokos.  1361.0
# ...          ...                                                ...     ...
# 438251         6  Pastatų, statinių remonto, apdailos (išskyrus ...   990.0
# 438253         6  Pastatų, statinių remonto, apdailos (išskyrus ...  2498.0
# 438258         9  Įmokų į pensijų fondą dalis, viršijanti 3 proc...   183.0
# 438259         8  Nepilnamečių (iki 18 metų) vaikų (įvaikių, glo...  1357.0
# 438261         6  Pastatų, statinių remonto, apdailos (išskyrus ...   790.0
#
# [1537 rows x 10 columns]

# %%
islaidos_miestui = islaidos.value_counts(['sav_pavadinimas', 'ir_kodas','pavadinimas']).sort_index()
islaidos_miestui.head()#rasti kiekveinai savivaldybei sriti, kur dazniausios/daugiausiai islaidu
islaidos_miestui['Neringos sav.'].nlargest(n=3) #trys popiliariausios tam mieste islaidu rusys)
# Out:
# ir_kodas  pavadinimas
# 1         Gyvybės draudimo įmokos.                              936
# 3         Būsto kredito, suteikto iki 2008-12-31, palūkanos.    250
# 2         Įmokos už aukštąjį ar profesinį mokymąsi.             130
# dtype: int64

# %%
islaidos['sav_pavadinimas'].unique()
# Out:
# array(['Kauno m. sav.', 'Vilniaus m. sav.', 'Vilkaviškio r. sav.',
#        'Alytaus m. sav.', 'Varėnos r. sav.', 'Jonavos r. sav.',
#        'Kauno r. sav.', 'Klaipėdos r. sav.', 'Klaipėdos m. sav.',
#        'Kretingos r. sav.', 'Druskininkų sav.', 'Trakų r. sav.',
#        'Vilniaus r. sav.', 'Šilutės r. sav.', 'Mažeikių r. sav.',
#        'Biržų r. sav.', 'Kėdainių r. sav.', 'Šiaulių r. sav.',
#        'Panevėžio r. sav.', 'Šakių r. sav.', 'Ignalinos r. sav.',
#        'Panevėžio m. sav.', 'Marijampolės sav.', 'Šiaulių m. sav.',
#        'Radviliškio r. sav.', 'Visagino sav.', 'Telšių r. sav.',
#        'Rokiškio r. sav.', 'Elektrėnų sav.', 'Alytaus r. sav.',
#        'Utenos r. sav.', 'Plungės r. sav.', 'Jurbarko r. sav.',
#        'Tauragės r. sav.', 'Švenčionių r. sav.', 'Kelmės r. sav.',
#        'Kazlų Rūdos sav.', 'Palangos m. sav.', 'Ukmergės r. sav.',
#        'Šilalės r. sav.', 'Raseinių r. sav.', 'Prienų r. sav.',
#        'Širvintų r. sav.', 'Kaišiadorių r. sav.', 'Pasvalio r. sav.',
#        'Skuodo r. sav.', 'Molėtų r. sav.', 'Pakruojo r. sav.',
#        'Neringos sav.', 'Kupiškio r. sav.', 'Lazdijų r. sav.',
#        'Joniškio r. sav.', 'Akmenės r. sav.', 'Zarasų r. sav.',
#        'Šalčininkų r. sav.', 'Rietavo sav.', 'Anykščių r. sav.',
#        'Birštono sav.', 'Kalvarijos sav.', 'Pagėgių sav.'], dtype=object)

# %%
islaidos_rusiai = islaidos.value_counts(['pavadinimas','sav_pavadinimas']).sort_index()
islaidos_rusiai.head()#rasti kiekveinai savivaldybei sriti, kur dazniausios/daugiausiai islaidu
islaidos_rusiai['Nepilnamečių (iki 18 metų) vaikų (įvaikių, globotinių, kuriems nustatyta nuolatinė globa šeimoje) priežiūros paslaugų išlaidos.'].nlargest(n=3)
# Out:
# sav_pavadinimas
# Vilniaus m. sav.    145
# Kauno m. sav.        41
# Kauno r. sav.        24
# dtype: int64

# %%
islaidos['pavadinimas'].unique()
# Out:
# array(['Įmokos už aukštąjį ar profesinį mokymąsi.',
#        'Gyvybės draudimo įmokos.',
#        'Pastatų, statinių remonto, apdailos (išskyrus renovaciją) darbų išlaidos.',
#        'Lengvųjų automobilių remonto paslaugų išlaidos (neįskaitant atsarginių detalių, eksploatacinių medžiagų kainos).',
#        'Būsto kredito, suteikto iki 2008-12-31, palūkanos.',
#        'Grąžintas studijų kreditas.', 'Pensijų kaupimo įmokos.',
#        'Įmokų į pensijų fondą dalis, viršijanti 3 procentus gyventojo pajamų, nuo kurių mokamos valstybinio socialinio draudimo įmokos.',
#        'Nepilnamečių (iki 18 metų) vaikų (įvaikių, globotinių, kuriems nustatyta nuolatinė globa šeimoje) priežiūros paslaugų išlaidos.'],
#       dtype=object)

# %%
islaidos['suma'].plot.box(logy = True)
# Out:
# <AxesSubplot:>

# %%
islaidos_sav.plot.box(logy = True)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=islaidos[islaidos['suma'] < 7000], x = 'suma', kde = True)
# Out:
# <AxesSubplot:xlabel='suma', ylabel='Count'>

# %%
sns.histplot(data=islaidos[islaidos['suma'] < 2000], x = 'suma')
# Out:
# <AxesSubplot:xlabel='suma', ylabel='Count'>

# %%
#######################################################################################################

# %%
#######################################################################################################

# %%
#Pajamos#

# %%
pajamos=pd.read_csv("GyventojuPajamos.csv")

# %%
pajamos.info() #kodėl nėra non-null ir count stulpeliu
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3562128 entries, 0 to 3562127
# Data columns (total 11 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   _type            object
#  1   _id              object
#  2   _revision        object
#  3   eil_num          int64
#  4   metai            int64
#  5   sav_kodas        int64
#  6   sav_pavadinimas  object
#  7   kodas_gpmi       object
#  8   kodas            int64
#  9   suma             float64
#  10  aprasas          object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 298.9+ MB

# %%
pajamos.nunique()
# Out:
# _type                    1
# _id                3562128
# _revision          3562128
# eil_num            1199181
# metai                    1
# sav_kodas               60
# sav_pavadinimas         60
# kodas_gpmi               5
# kodas                   71
# suma                 51247
# aprasas                 71
# dtype: int64

# %%
pajamos.head(10)
# Out:
#                                                _type  \
# 0  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 1  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 2  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 3  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 4  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 5  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 6  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 7  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 8  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 9  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
#
#                                     _id                             _revision  \
# 0  265387a6-5532-4fd6-983e-ef6c10bddcda  7aba9fcc-559c-4e1a-85d1-0c5c8d8c8705
# 1  1ffc5a26-156b-4000-a687-2965b8439124  71ccd7c9-e7c6-4b9c-b4c7-20b0aa179494
# 2  15ed0e94-b556-491e-9499-b519b8c6a442  33754b81-8869-4687-8c95-5c7c9ab4aa24
# 3  fd386153-002d-49f2-908e-5d851a0a8fe6  ebbd67b7-e9f9-49a1-9914-0748636b209f
# 4  fe5e66d2-7e34-4cf7-9c3a-d85bb46770a2  4709f12a-0074-4ac0-aa80-c6ee94c6497e
# 5  d82a552b-efd8-445c-8b8f-f9617677e64d  bb1689b8-0878-4d59-b5af-36d43d3d3379
# 6  fbed97fe-a99a-4f39-a66e-6451d5c504af  af2ea638-edec-4801-8247-71827ca4a4d0
# 7  bac943ec-2cf3-455c-af9f-fae8c5e247c4  bf6b7b27-b00e-4f2f-9958-183945a87aee
# 8  637192ad-fa35-43bf-bb92-5ba585a09f27  f5c809a9-f67e-42c3-958a-a8e402b20c77
# 9  9738b239-51b5-465a-9ace-1708a75d327e  0cfa9ec5-e2b4-47b5-adc0-0d75c6fd196a
#
#    eil_num  metai  sav_kodas  sav_pavadinimas kodas_gpmi  kodas     suma  \
# 0        1   2020         11  Alytaus m. sav.          B      5    144.0
# 1        2   2020         11  Alytaus m. sav.          B      5     30.0
# 2        3   2020         11  Alytaus m. sav.          B      5   7288.0
# 3        4   2020         11  Alytaus m. sav.          B      5    949.0
# 4        5   2020         11  Alytaus m. sav.          B      5     88.0
# 5        6   2020         11  Alytaus m. sav.          B      5    924.0
# 6        7   2020         11  Alytaus m. sav.          B      5     30.0
# 7        8   2020         11  Alytaus m. sav.          B      5     94.0
# 8        9   2020         11  Alytaus m. sav.          B      5  11843.0
# 9       10   2020         11  Alytaus m. sav.          B      5   1914.0
#
#                                              aprasas
# 0  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 1  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 2  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 3  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 4  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 5  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 6  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 7  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 8  Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 9  Dienpinigiai, išmokėti į komandiruotę išsiųsti...

# %%
#RUSYS#

# %%
pajamos_rusys=pajamos.groupby(['kodas', 'aprasas']).sum(['suma']).drop(['eil_num','sav_kodas', 'metai'],axis=1)
pajamos_rusys #pagal islaidu rusies kodus ir aprasus susumuota islaidu sumos
# Out:
#                                                                   suma
# kodas aprasas
# 1     Su darbo santykiais arba jų esmę atitinkančiais...  1.770912e+10
# 2     Neribotos civilinės atsakomybės vieneto savo da...  4.298645e+07
# 3     Ligos, motinystės, tėvystės, vaiko priežiūros i...  7.958575e+08
# 4     Iki 2018 m. gruodžio 31 d. apskaičiuotos su dar...  1.698764e+07
# 5     Dienpinigiai, išmokėti į komandiruotę išsiųstie...  7.120805e+08
# ...                                                                ...
# 90    Gyventojams pagal verslo liudijimą (051 veiklos...  8.992684e+07
# 92    Individualią veiklą pagal verslo liudijimą vykd...  6.017038e+08
# 93    Individualią veiklą vykdančiam gyventojui išmok...  1.436857e+09
# 96    Šeimynos dalyvio išlaikymo pajamos, gautos paga...  4.139870e+05
# 97    Žemės ūkio veikloje naudojamo ilgalaikio turto ...  2.606387e+07
#
# [71 rows x 1 columns]

# %%
plt.rcParams['figure.figsize']=[20,10]
pajamos_rusys.reset_index().plot(x='kodas', y = 'suma', c = 'blue', marker = 'o',  markersize=3, grid = True).legend(labels = ['Suma'])
plt.xlabel("Pajamų kilmės kodas")
plt.ylabel("Pajamų suma")
# Out:
# Text(0, 0.5, 'Pajamų suma')

# %%
pajamos_dazniai=pajamos.value_counts(['kodas', 'aprasas']).sort_index()
pajamos_dazniai
#cia suskaiciuota kiek kiekvienos rusies (pagal koda ir pavadinima) yra islaidu duomenyse
# Out:
# kodas  aprasas
# 1      Su darbo santykiais arba jų esmę atitinkančiais santykiais susijusios išmokos (įskaitant atleidžiamas nuo pajamų mokesčio pagal GPMĮ 37 straipsnį), išskyrus žymimas 04 ir 08 kodais                                                                                                          1199181
# 2      Neribotos civilinės atsakomybės vieneto savo dalyviui ar mažosios bendrijos savo nariui – nuolatiniam ir nenuolatiniam Lietuvos gyventojui – išmokėtos išmokos, pagal GPMĮ 2 straipsnio 34 dalį priskiriamos su darbo santykiais ar jų esmę atitinkančiais santykiais susijusioms pajamoms       7310
# 3      Ligos, motinystės, tėvystės, vaiko priežiūros ir ilgalaikio darbo išmokos                                                                                                                                                                                                                      601656
# 4      Iki 2018 m. gruodžio 31 d. apskaičiuotos su darbo santykiais arba jų esmę  atitinkančiais santykiais susijusios išmokos, išmokėtos 2019 metais ir vėlesniais mokestiniais laikotarpiais                                                                                                         22761
# 5      Dienpinigiai, išmokėti į komandiruotę išsiųstiems darbuotojams LR Vyriausybės 2003 m. sausio 28 d. nutarimo Nr. 99 „Dėl Komandiruočių sąnaudų atskaitymo iš pajamų taisyklių patvirtinimo“ nustatyta tvarka                                                                                    157040
#                                                                                                                                                                                                                                                                                                       ...
# 90     Gyventojams pagal verslo liudijimą (051 veiklos rūšis) už gyvenamosios paskirties patalpų nuomą išmokėtos išmokos                                                                                                                                                                               13168
# 92     Individualią veiklą pagal verslo liudijimą vykdančiam gyventojui išmokėtos išmokos                                                                                                                                                                                                              74231
# 93     Individualią veiklą vykdančiam gyventojui išmokėtos išmokos, išskyrus žymimas 35, 90, 92 ir 96 kodais                                                                                                                                                                                          182334
# 96     Šeimynos dalyvio išlaikymo pajamos, gautos pagal LR šeimynų įstatymą                                                                                                                                                                                                                               74
# 97     Žemės ūkio veikloje naudojamo ilgalaikio turto (išskyrus nekilnojamojo) perleidimo nuosavybėn pajamos                                                                                                                                                                                            1446
# Length: 71, dtype: int64

# %%
mpl.rc('figure', figsize=(20,10))
pajamos_dazniai.reset_index().plot(x='kodas', y = 0, c = 'blue', marker = 'o',  markersize=3, grid = True).legend(labels = ['Dažniai'])
plt.xlabel("Pajamų kilmės kodas")
plt.ylabel("Dažniai")
# Out:
# Text(0, 0.5, 'Dažniai')

# %%
pajamos_vidurkiai=pajamos.groupby(['aprasas','kodas']).mean().round(2).sort_values(by = 'kodas').drop(['metai','sav_kodas','eil_num'], axis=1)
pajamos_vidurkiai
# Out:
#                                                               suma
# aprasas                                            kodas
# Su darbo santykiais arba jų esmę atitinkančiais... 1      14767.68
# Neribotos civilinės atsakomybės vieneto savo da... 2       5890.98
# Ligos, motinystės, tėvystės, vaiko priežiūros i... 3       1322.78
# Iki 2018 m. gruodžio 31 d. apskaičiuotos su dar... 4        746.35
# Dienpinigiai, išmokėti į komandiruotę išsiųstie... 5       4534.45
# ...                                                            ...
# Gyventojams pagal verslo liudijimą (051 veiklos... 90      6836.46
# Individualią veiklą pagal verslo liudijimą vykd... 92      8105.83
# Individualią veiklą vykdančiam gyventojui išmok... 93      7880.36
# Šeimynos dalyvio išlaikymo pajamos, gautos paga... 96      6571.22
# Žemės ūkio veikloje naudojamo ilgalaikio turto ... 97     18226.48
#
# [71 rows x 1 columns]

# %%
mpl.rc('figure', figsize=(20,10))
pajamos_vidurkiai.reset_index().plot(x='kodas', y='suma', c = 'red', marker = 'o',  markersize=7, grid = True).legend(labels = ['Vidurkiai'])
plt.xlabel("Pajamų rūšies kodas")
plt.ylabel("2020 m. vidurkis")
# Out:
# Text(0, 0.5, '2020 m. vidurkis')

# %%
pajamos_dv = [pajamos_dazniai,pajamos_vidurkiai]
result=pd.concat(pajamos_dv)
result.hist()
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'suma'}>]], dtype=object)

# %%
#SAVIVALDYBES#

# %%
pajamos_sav=pajamos.groupby(['sav_kodas', 'sav_pavadinimas']).sum(['suma']).sort_values(by ='sav_kodas').drop(['metai','kodas','eil_num'],axis=1)
pajamos_sav.head(10) #kiek kiekvienam rusies savivaldybes kodui priklauso islaidu
# Out:
#                                      suma
# sav_kodas sav_pavadinimas
# 11        Alytaus m. sav.    3.982674e+08
# 12        Birštono sav.      4.181287e+07
# 13        Vilniaus m. sav.   8.045342e+09
# 15        Druskininkų sav.   1.552916e+08
# 18        Marijampolės sav.  4.327186e+08
# 19        Kauno m. sav.      3.232171e+09
# 21        Klaipėdos m. sav.  1.514659e+09
# 23        Neringos sav.      2.073766e+08
# 25        Palangos m. sav.   2.241450e+08
# 27        Panevėžio m. sav.  7.307646e+08

# %%
plt.rcParams['figure.figsize']=[20,10]
pajamos_sav.reset_index().plot(x = 'sav_kodas', y = 'suma', c = 'blue', marker = 'o',  markersize=3, grid = True).legend(labels = ['Suma'])
plt.xlabel("Savivaldybės kodas")
plt.ylabel("Savivaldybės pajamų suma (2020 m.)")
#kaip paimti atskirus daugiausiai (ar mažiausiai) išleidžiančius miestus, padidinti tikslumą diagramoje
# Out:
# Text(0, 0.5, 'Savivaldybės pajamų suma (2020 m.)')

# %%
dazniai_sav_paj=pajamos.value_counts(['sav_kodas','sav_pavadinimas']).sort_index()
dazniai_sav_paj.head(10)
# Out:
# sav_kodas  sav_pavadinimas
# 11         Alytaus m. sav.       62313
# 12         Birštono sav.          5564
# 13         Vilniaus m. sav.     775608
# 15         Druskininkų sav.      24000
# 18         Marijampolės sav.     65672
# 19         Kauno m. sav.        366019
# 21         Klaipėdos m. sav.    187521
# 23         Neringos sav.         10507
# 25         Palangos m. sav.      22184
# 27         Panevėžio m. sav.    109067
# dtype: int64

# %%
mpl.rc('figure', figsize=(20,10))
dazniai_sav_paj.reset_index().plot(x='sav_kodas', y = 0, c = 'blue', marker = 'o',  markersize=3, grid = True).legend(labels = ['Dažniai'])
plt.xlabel("Savivaldybės kodas")
plt.ylabel("Dažniai")
# Out:
# Text(0, 0.5, 'Dažniai')

# %%
vidurkiai_sav_paj=pajamos.groupby(['sav_kodas','sav_pavadinimas']).mean().round(2).drop(['metai', 'kodas', 'eil_num'], axis=1).sort_index()
vidurkiai_sav_paj.head(10)
# Out:
#                                  suma
# sav_kodas sav_pavadinimas
# 11        Alytaus m. sav.     6392.22
# 12        Birštono sav.       7532.49
# 13        Vilniaus m. sav.   10372.98
# 15        Druskininkų sav.    6474.26
# 18        Marijampolės sav.   6589.39
# 19        Kauno m. sav.       8830.75
# 21        Klaipėdos m. sav.   8077.71
# 23        Neringos sav.      19759.56
# 25        Palangos m. sav.   10109.83
# 27        Panevėžio m. sav.   6700.82

# %%
mpl.rc('figure', figsize=(20,10))
vidurkiai_sav_paj.reset_index().plot(x='sav_kodas', y='suma', c = 'red', marker = 'o',  markersize=7, grid = True).legend(labels = ['Vidurkiai'])
plt.xlabel("Savivaldybės kodas")
plt.ylabel("Pajamų savivaldybėse vidurkiai (2020 m.)")
# Out:
# Text(0, 0.5, 'Pajamų savivaldybėse vidurkiai (2020 m.)')

# %%
pajamos.loc[pajamos['sav_kodas'] == 23]
# Out:
#                                                      _type  \
# 13399    datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 13400    datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 13401    datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 13402    datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 13403    datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# ...                                                    ...
# 3423575  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 3423576  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 3423577  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 3423578  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
# 3423579  datasets/gov/vmi/gyventoju_pajamos/GyventojuPa...
#
#                                           _id  \
# 13399    5ee110e1-3f7e-4c53-b2cc-01e0cacd00ba
# 13400    ad78151d-cbd3-4701-8132-2eb5e44828c2
# 13401    bf891bf5-c6cb-47ae-b3ea-f7cc3ba8326f
# 13402    e3721070-51ef-4d60-8cee-dc3b43d9124b
# 13403    a305d167-b030-4af3-9d68-45fb7ecb3cb9
# ...                                       ...
# 3423575  7bccab0b-c860-40b6-b71b-f2c2a14a1523
# 3423576  3ea8f409-3c14-442b-85ce-f8f1c2de3701
# 3423577  4c289533-d56b-4879-a4d4-902d7f0f1dba
# 3423578  7cc41ad5-0442-4f91-869e-75df3f011186
# 3423579  6bc06881-04ef-4d92-8545-af523643b5cc
#
#                                     _revision  eil_num  metai  sav_kodas  \
# 13399    f284e704-6a03-48e2-8cc9-2c37466c01ef    13400   2020         23
# 13400    f04febe0-98ba-4023-918f-26bef935e154    13401   2020         23
# 13401    0d497461-2258-48ec-9499-a8cedade906f    13402   2020         23
# 13402    43c42d9d-677b-44b1-9bb3-c70110583633    13403   2020         23
# 13403    67724cea-5889-40a5-b27c-fe6ea8f313d8    13404   2020         23
# ...                                       ...      ...    ...        ...
# 3423575  79b220ce-e0fd-41d7-bb82-2066163e5c39  1060629   2020         23
# 3423576  41bb182c-014a-44a6-bc7f-149c9e1bbb3c  1060630   2020         23
# 3423577  eba2ba3e-abd1-4315-9113-7fe7dc473dbe  1060631   2020         23
# 3423578  c281caf5-4436-46f7-8589-09316f7d632b  1060632   2020         23
# 3423579  0e6216f9-d152-46ec-8251-c52873c12f8a  1060633   2020         23
#
#         sav_pavadinimas kodas_gpmi  kodas     suma  \
# 13399     Neringos sav.          B      5   7418.0
# 13400     Neringos sav.          B      5    366.0
# 13401     Neringos sav.          B      5    249.0
# 13402     Neringos sav.          B      5    400.0
# 13403     Neringos sav.          B      5    297.0
# ...                 ...        ...    ...      ...
# 3423575   Neringos sav.          B      1  12987.0
# 3423576   Neringos sav.          B      1  14662.0
# 3423577   Neringos sav.          B      1  36401.0
# 3423578   Neringos sav.          B      1  98127.0
# 3423579   Neringos sav.          B      1  17874.0
#
#                                                    aprasas
# 13399    Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 13400    Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 13401    Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 13402    Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# 13403    Dienpinigiai, išmokėti į komandiruotę išsiųsti...
# ...                                                    ...
# 3423575  Su darbo santykiais arba jų esmę atitinkančiai...
# 3423576  Su darbo santykiais arba jų esmę atitinkančiai...
# 3423577  Su darbo santykiais arba jų esmę atitinkančiai...
# 3423578  Su darbo santykiais arba jų esmę atitinkančiai...
# 3423579  Su darbo santykiais arba jų esmę atitinkančiai...
#
# [10507 rows x 11 columns]

# %%
miestui_paj = pajamos.value_counts(['sav_pavadinimas', 'kodas','aprasas']).sort_index()
miestui_paj.head()#rasti kiekveinai savivaldybei sriti, kur dazniausios/daugiausiai islaidu
miestui_paj['Alytaus m. sav.'].nlargest(n=3) #trys popiliariausios tam mieste islaidu rusys) ir taip su visais kazka bendro
# Out:
# kodas  aprasas
# 1      Su darbo santykiais arba jų esmę atitinkančiais santykiais susijusios išmokos (įskaitant atleidžiamas nuo pajamų mokesčio pagal GPMĮ 37 straipsnį), išskyrus žymimas 04 ir 08 kodais    21913
# 3      Ligos, motinystės, tėvystės, vaiko priežiūros ir ilgalaikio darbo išmokos                                                                                                               10998
# 7      Asmens, susijusio su gyventoju darbo santykiais ar jų esmę atitinkančiais santykiais, išmokėtų prizų vertė, per mokestinį laikotarpį neviršijanti 200 eurų                               4594
# dtype: int64

# %%
pajamos['sav_pavadinimas'].unique()
# Out:
# array(['Alytaus m. sav.', 'Birštono sav.', 'Vilniaus m. sav.',
#        'Druskininkų sav.', 'Marijampolės sav.', 'Kauno m. sav.',
#        'Klaipėdos m. sav.', 'Neringos sav.', 'Palangos m. sav.',
#        'Panevėžio m. sav.', 'Šiaulių m. sav.', 'Visagino sav.',
#        'Akmenės r. sav.', 'Alytaus r. sav.', 'Anykščių r. sav.',
#        'Biržų r. sav.', 'Varėnos r. sav.', 'Vilkaviškio r. sav.',
#        'Vilniaus r. sav.', 'Elektrėnų sav.', 'Zarasų r. sav.',
#        'Ignalinos r. sav.', 'Jonavos r. sav.', 'Joniškio r. sav.',
#        'Kalvarijos sav.', 'Kaišiadorių r. sav.', 'Kauno r. sav.',
#        'Kėdainių r. sav.', 'Kelmės r. sav.', 'Klaipėdos r. sav.',
#        'Kretingos r. sav.', 'Kupiškio r. sav.', 'Kazlų Rūdos sav.',
#        'Lazdijų r. sav.', 'Mažeikių r. sav.', 'Molėtų r. sav.',
#        'Pagėgių sav.', 'Pakruojo r. sav.', 'Panevėžio r. sav.',
#        'Pasvalio r. sav.', 'Plungės r. sav.', 'Prienų r. sav.',
#        'Radviliškio r. sav.', 'Raseinių r. sav.', 'Rokiškio r. sav.',
#        'Rietavo sav.', 'Skuodo r. sav.', 'Tauragės r. sav.',
#        'Telšių r. sav.', 'Trakų r. sav.', 'Ukmergės r. sav.',
#        'Utenos r. sav.', 'Šakių r. sav.', 'Šalčininkų r. sav.',
#        'Švenčionių r. sav.', 'Šilalės r. sav.', 'Šilutės r. sav.',
#        'Širvintų r. sav.', 'Šiaulių r. sav.', 'Jurbarko r. sav.'],
#       dtype=object)

# %%
rusiai_paj = pajamos.value_counts(['aprasas','sav_pavadinimas']).sort_index()
rusiai_paj.head()#rasti kiekveinai savivaldybei sriti, kur dazniausios/daugiausiai islaidu
rusiai_paj['Azartinių lošimų laimėjimų pajamos'].nlargest(n=3)
# Out:
# sav_pavadinimas
# Vilniaus m. sav.     353
# Kauno m. sav.        175
# Klaipėdos m. sav.     87
# dtype: int64

# %%
pajamos['aprasas'].unique()
# Out:
# array(['Dienpinigiai, išmokėti į komandiruotę išsiųstiems darbuotojams LR Vyriausybės 2003 m. sausio 28 d. nutarimo Nr. 99 „Dėl Komandiruočių sąnaudų atskaitymo iš pajamų taisyklių patvirtinimo“ nustatyta tvarka',
#        'Su darbo santykiais arba jų esmę atitinkančiais santykiais susijusios išmokos, kurios neapmokestinamos pagal GPMĮ 17 straipsnį, išskyrus žymimas 05, 06 ir 07 kodais',
#        'Ligos išmokos jūrininkams, kurios neapmokestinamos pagal GPMĮ 17 straipsnio 1 dalies 45 punktą',
#        'Privalomai registruotino kilnojamojo daikto arba daikto, kuris nekilnojamuoju pripažįstamas pagal įstatymus, pardavimo ar kitokio perleidimo nuosavybėn pajamos',
#        'Būsto (įskaitant priskirtą žemę) pardavimo ar kitokio perleidimo nuosavybėn pajamos',
#        'Nekilnojamojo pagal prigimtį daikto pardavimo ar kitokio perleidimo nuosavybėn išmokos (išskyrus žymimas 18 kodu)',
#        'Nekilnojamojo pagal prigimtį daikto nuomos pajamos',
#        'Išmokos iš paskirstytojo pelno (dividendai)',
#        'Neribotos civilinės atsakomybės vieneto savo dalyviui išmokėtos išmokos iš pelno',
#        'Pajamos iš individualios žemės ūkio veiklos',
#        'Prizai  ir laimėjimai, gauti ne iš darbdavio, išskyrus žymimas 07, 42 ir 43 kodais',
#        'Dovanos, gautos iš kitų gyventojų, išskyrus žymimas 49 kodu',
#        'Loterijų laimėjimai, gauti iš EEE vienetų, kurie šių valstybių teisės aktų nustatyta tvarka moka mokestį nuo loterijų apyvartos',
#        'Dovanos, gautos iš juridinių asmenų (nesusijusių su darbo ar jų esmę atitinkančiais santykiais)',
#        'Stipendijos, išskyrus žymimas 45 kodu',
#        'Atlikėjo veiklos pajamos, gautos iš asmens, nesusijusio su darbo ar jų esmę atitinkančiais santykiais, ir ne iš individualios veiklos',
#        'Darbdavio išmokėti autoriniai atlyginimai',
#        'Palūkanos už vartojimo kreditą, suteiktą per tarpusavio skolinimo platformą, ir / ar palūkanos už lėšas, suteiktas per sutelktinio finansavimo platformą (nuo 2018-01-01)',
#        'Ne darbdavio išmokėti autoriniai atlyginimai',
#        'Pavėluoto mokėjimo palūkanos, numatytos atsiskaitymą už žemės ūkio produkciją reglamentuojančiuose LR teisės aktuose',
#        'Kitos su darbo santykiais nesusijusios ir ne individualios veiklos apmokestinamosios išmokos, kurioms žymėti nėra nustatytas specialus kodas',
#        'Pensijų kaupimo išmokos, ne didesnės už sumokėtas įmokas',
#        'Gyvybės draudimo išmokos, viršijančios sumokėtas įmokas',
#        'Pagal paslaugų sutartį už ne individualios veiklos paslaugas išmokėtos apmokestinamosios išmokos, išskyrus išmokas, kurioms žymėti nustatytas specialus kodas',
#        'GPMĮ 17 straipsnio 1 dalyje nurodytos neapmokestinamosios išmokos (išskyrus neapmokestinamas išmokas, kurioms žymėti nustatytas specialus kodas)',
#        'MB vadovui (ne nariui) pagal civilinę paslaugų sutartį už vadovavimo veiklą išmokėtos išmokos',
#        'Gyventojams pagal verslo liudijimą (051 veiklos rūšis) už gyvenamosios paskirties patalpų nuomą išmokėtos išmokos',
#        'Individualią veiklą vykdančiam gyventojui išmokėtos išmokos, išskyrus žymimas 35, 90, 92 ir 96 kodais',
#        'Šeimynos dalyvio išlaikymo pajamos, gautos pagal LR šeimynų įstatymą',
#        'Asmens, susijusio su gyventoju darbo santykiais ar jų esmę atitinkančiais santykiais, išmokėtų prizų vertė, per mokestinį laikotarpį neviršijanti 200 eurų',
#        'Finansinių priemonių pardavimo ar kitokio perleidimo nuosavybėn išmokos ir išvestinių finansinių priemonių realizavimo išmokos, kurioms taikoma GPMĮ 17 straipsnio 1 dalies 30 punkto lengvata',
#        'Ne individualios veiklos atliekų pardavimo ar kitokio perleidimo nuosavybėn išmokos',
#        'Azartinių lošimų laimėjimų pajamos',
#        'Kooperatinės bendrovės (kooperatyvo) dalyvio (nario) pajamos iš paskirstytojo pelno',
#        'Sporto varžybų prizas (išskyrus žymimus 31 kodu), jeigu šį prizą įsteigia ir skiria olimpiniam, parolimpiniam, regos, klausos ar judėjimo negalią turinčių asmenų sporto judėjimams Lietuvoje vadovaujančios nevyriausybinės organizacijos, tarptautinės sporto šakų federacijos ar šių federacijų nariai, Lietuvos sporto šakų federacijos',
#        'Pajamos už parduodamas paties gyventojo surinktas miško gėrybes (grybus, uogas, riešutus, vaistažoles)',
#        'Sporto veiklos pajamos, gautos iš asmens, nesusijusio su darbo ar jų esmę atitinkančiais santykiais, ir ne iš individualios veiklos',
#        'Kitos palūkanos, išskyrus žymimas 56, 58, 64, 65, 66, 67, 68 ir 69 kodais',
#        'Indėlių palūkanos pagal sutartis, sudarytas nuo 2014 m. sausio 1 d.',
#        'Darbuotojo naudai darbdavio mokamų draudimo įmokų už papildomą (savanorišką) sveikatos draudimą suma, kuri pagal GPMĮ 17 straipsnio 1 dalies 14 punkto arba 141 punkto nuostatas neapmokestinama pajamų mokesčiu',
#        'Iki 2018 m. gruodžio 31 d. apskaičiuotos su darbo santykiais arba jų esmę  atitinkančiais santykiais susijusios išmokos, išmokėtos 2019 metais ir vėlesniais mokestiniais laikotarpiais',
#        'Kito turto pardavimo ar kitokio perleidimo nuosavybėn išmokos, išskyrus žymimas 10, 11, 12, 16, 17, 18 ir 34 kodais',
#        'Finansinių priemonių pardavimo ar kitokio perleidimo nuosavybėn išmokos ir išvestinių finansinių priemonių realizavimo išmokos, kurioms netaikoma GPMĮ 17 straipsnio 1 dalies 30 punkto lengvata',
#        'Nenukirsto miško, apvaliosios medienos pardavimo ar kitokio perleidimo nuosavybėn pajamos (išmokėtoms išmokoms  2007 ir vėlesniais metais)',
#        'Tiesioginės išmokos, išmokėtos pagal LR Žemės ūkio, maisto ūkio ir kaimo plėtros įstatymą bei pagal kitus tokių išmokų mokėjimą reglamentuojančius teisės aktus',
#        'Gyventojui išmokėta premija, kuri pagal GPMĮ 17 straipsnio 1 dalies 36 punkto nuostatas neapmokestinama pajamų mokesčiu',
#        'Honorarai',
#        'Pelno nesiekiančių vienetų iš lėšų, sukauptų iš nario mokesčio, savo nariams išmokėtos pašalpos, išskyrus pašalpas, išmokėtas vieneto, su gyventoju susijusio darbo santykiais ar jų esmę atitinkančiais santykiais',
#        'Vieneto (išskyrus pelno nesiekiantį vienetą) mokymo įstaigų studentams ir moksleiviams pagal vieneto, mokymo įstaigos ir studento ar moksleivio pasirašytas trišales sutartis mokama stipendija, skirta studento ar moksleivio mokymosi ir pragyvenimo reikmėms apmokėti, jeigu stipendijos mokėjimo laikotarpiu stipendijos gavėjas nėra stipendiją mokančio vieneto daugiau kaip 10 procentų akcijų (dalių, pajų) savininkas, darbuotojas arba stipendiją mokančio vieneto daugiau kaip 10 procentų akcijų (dalių, pajų) savininko arba darbuotojo šeimos narys ir tokia stipendija nėra susijusi su stipendijos gavėjo šiems vienetams atliktais arba atliekamais darbais, suteiktomis arba teikiamomis paslaugomis, kai metinė stipendijos suma viršija 2 500 eurų',
#        'Dovanos, gautos iš sutuoktinių, tėvų, įtėvių, vaikų, įvaikių, brolių, seserų, senelių, vaikaičių',
#        'Palūkanos už EEE valstybių vyriausybių arba jų politinių ar teritorijos administracinių padalinių vertybinius popierius, įsigytus iki 2013 m. gruodžio 31 d.',
#        'Palūkanos už ne nuosavybės vertybinius popierius*, įsigytus iki 2013 m. gruodžio 31 d. ir pradėtus išpirkti ne anksčiau kaip po 366 dienų nuo išleidimo dienos',
#        'Gyvybės draudimo išmokos, ne didesnės už sumokėtas įmokas',
#        'Darbuotojo naudai darbdavio mokamų gyvybės draudimo įmokų ir pensijų įmokų suma, kuri pagal GPMĮ 17 straipsnio 1 dalies 14 punkto arba 141 punkto nuostatas neapmokestinama pajamų mokesčiu',
#        'Pensijų kaupimo išmokos, viršijančios sumokėtas įmokas',
#        'Ligos, motinystės, tėvystės, vaiko priežiūros ir ilgalaikio darbo išmokos',
#        'Neribotos civilinės atsakomybės vieneto savo dalyviui ar mažosios bendrijos savo nariui – nuolatiniam ir nenuolatiniam Lietuvos gyventojui – išmokėtos išmokos, pagal GPMĮ 2 straipsnio 34 dalį priskiriamos su darbo santykiais ar jų esmę atitinkančiais santykiais susijusioms pajamoms',
#        'LR Vyriausybės 2003 m. sausio 28 d. nutarimo Nr. 116 „Dėl Kompensuojamų išmokų dydžio ir mokėjimo tvarkos aprašo patvirtinimo“ nustatyta tvarka išmokėtos padidėjusių išlaidų kompensacijos darbuotojams, kurių darbas atliekamas kelionėje, lauko sąlygomis, susijęs su važiavimais arba yra kilnojamojo pobūdžio',
#        'Kito turto nuomos pajamos, išskyrus žymimas 23 kodu',
#        'Kompensacinės išmokos, išmokėtos pagal LR Žemės ūkio, maisto ūkio ir kaimo plėtros įstatymą bei pagal kitus tokių išmokų mokėjimą reglamentuojančius teisės aktus',
#        'Valdybos ir stebėtojų tarybos nariui išmokėtos metinės išmokos (tantjemos) ir/arba pajamos už vykdytas valdymo funkcijas',
#        'Pensijų išmokos (pensijos, pensijų anuitetai)',
#        'Palūkanos už paskolas',
#        'Pelno nesiekiančio vieneto gyventojui išmokėta premija, kuri pagal GPMĮ 17 straipsnio 1 dalies 52 punkto nuostatas neapmokestinama pajamų mokesčiu',
#        'Indėlių palūkanos, gautos už EEE valstybių kredito įstaigose laikomus indėlius pagal sutartis, sudarytas iki 2013 m. gruodžio 31 d.',
#        'Palūkanos už ne nuosavybės vertybinius popierius* (įskaitant Lietuvos ir užsienio valstybių vyriausybių, taip pat jų politinių ar teritorijos administracinių padalinių ar vietos valdžios ne nuosavybės vertybinius popierius), įsigytus nuo 2014 m. sausio 1 d.',
#        'Paveldėjimo būdu gautos pajamos',
#        'Pagal paslaugų kvitą gautos pajamos',
#        'Individualią veiklą pagal verslo liudijimą vykdančiam gyventojui išmokėtos išmokos',
#        'Žemės ūkio veikloje naudojamo ilgalaikio turto (išskyrus nekilnojamojo) perleidimo nuosavybėn pajamos',
#        'Su darbo santykiais arba jų esmę atitinkančiais santykiais susijusios išmokos (įskaitant atleidžiamas nuo pajamų mokesčio pagal GPMĮ 37 straipsnį), išskyrus žymimas 04 ir 08 kodais'],
#       dtype=object)

# %%
pajamos['suma'].plot.box(logy = True)
# Out:
# <AxesSubplot:>

# %%
pajamu_sav['suma'].plot.box(logy = True)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(data=pajamos[pajamos['suma'] <20000], x = 'suma')
# Out:
# <AxesSubplot:xlabel='suma', ylabel='Count'>

# %%
sns.histplot(data=pajamos[pajamos['suma'] <1000], x = 'suma')
# Out:
# <AxesSubplot:xlabel='suma', ylabel='Count'>

# %%
pajamos['suma'].min() #kodel and dia kitaip
# Out:
# -336.0
